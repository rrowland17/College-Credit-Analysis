# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
CTE_student_data = './Clean_and_Combine.csv'
CTE_student_df = pd.read_csv(CTE_student_data)

CTE_student_df.head()
# Out:
#    DISTRICT  SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0      1902  3101100          PRECALCULUS (PRE CALC)                9.0
# 1      1902  3220300             ENGLISH III (ENG 3)               12.0
# 2      1902  3220400              ENGLISH IV (ENG 4)               10.0
# 3      1902  3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4      1902  3330100  UNITED STATES GOVERNMENT (GOVT                3.0
#
#    CTE_HOURS_2015  CTE_AVG_2015  ALL_STUDENTS_2015  ALL_HOURS_2015  \
# 0            36.0           4.0               18.0            54.0
# 1            48.0           4.0               12.0            48.0
# 2            57.0           5.7               14.0            81.0
# 3             3.0           3.0                3.0             3.0
# 4             3.0           3.0                3.0             3.0
#
#    ALL_AVG_2015  CTE_STUDENTS_2016  ...  ALL_AVG_2017  CTE_STUDENTS_2018  \
# ...

# %%
# Calculate the sum for cte students
cte_students_2015 = CTE_student_df["CTE_STUDENTS_2015"].sum()
cte_students_2016 = CTE_student_df["CTE_STUDENTS_2016"].sum()
cte_students_2017 = CTE_student_df["CTE_STUDENTS_2017"].sum()
cte_students_2018 = CTE_student_df["CTE_STUDENTS_2018"].sum()
all_students_2015 = CTE_student_df["ALL_STUDENTS_2015"].sum()
all_students_2016 = CTE_student_df["ALL_STUDENTS_2016"].sum()
all_students_2017 = CTE_student_df["ALL_STUDENTS_2017"].sum()
all_students_2018 = CTE_student_df["ALL_STUDENTS_2018"].sum()

# %%
# Create a group based on the values in the 'maker' column
district_group = CTE_student_df.groupby('District')

district_group.head()
# Out:
#        DISTRICT   SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0          1902   3101100          PRECALCULUS (PRE CALC)                9.0
# 1          1902   3220300             ENGLISH III (ENG 3)               12.0
# 2          1902   3220400              ENGLISH IV (ENG 4)               10.0
# 3          1902   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4          1902   3330100  UNITED STATES GOVERNMENT (GOVT                3.0
# 7          1904   3220300             ENGLISH III (ENG 3)               10.0
# 8          1904   3220400              ENGLISH IV (ENG 4)               11.0
# 9          1904   3241400      COMMUNICATION APPLICATIONS                3.0
# 10         1904   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 11         1904   3330100  UNITED STATES GOVERNMENT (GOVT                3.0
# 16         1906   3101100          PRECALCULUS (PRE CALC)                3.0
# ...

# %%
Percent_enrolled_2015 = (cte_students_2015/all_students_2015)*100
Percent_enrolled_2016 = (cte_students_2016/all_students_2016)*100
Percent_enrolled_2017 = (cte_students_2017/all_students_2017)*100
Percent_enrolled_2018 = (cte_students_2018/all_students_2018)*100

# %%
Percent_students = [Percent_enrolled_2015,Percent_enrolled_2016,Percent_enrolled_2017,Percent_enrolled_2018]
Percent_students_arr = tuple(Percent_students)

# %%
x_axis = [2015,2016,2017,2018]

# %%
# Count how many total students are in CTE in each district
sum_cte_district = district_group['CTE_STUDENTS_2018'].sum()

sum_cte_district
# Out:
# District
# A+ ACADEMY                          105.0
# ABBOTT ISD                           44.0
# ABERNATHY ISD                        79.0
# ABILENE ISD                         319.0
# ACADEMY ISD                          69.5
# ADRIAN ISD                           44.0
# ADVANTAGE ACADEMY                     0.0
# AGUA DULCE ISD                       17.0
# ALAMO HEIGHTS ISD                    82.3
# ALBA-GOLDEN ISD                     183.0
# ALBANY ISD                          103.0
# ALDINE ISD                         1931.0
# ALEDO ISD                           180.0
# ALICE ISD                           358.0
# ALIEF ISD                          2057.0
# ALLEN ISD                           814.5
# ALPINE ISD                           68.0
# ALTO ISD                              3.0
# ALVARADO ISD                        228.0
# ALVIN ISD                          1602.0
# ALVORD ISD                           62.0
# AMARILLO ISD                       1405.0
# ...

# %%
plt.plot(x_axis, Percent_students_arr)
# Give our graph axis labels
plt.xticks(range(2015, 2019, 1))
plt.xlabel("Years")
plt.ylabel("Percentage of CTE student enrollment")
plt.title('% of all students taking CTE courses over years 2015-2018')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Save an image of the chart and print it to the screen
plt.savefig("./Images/All_CTE_percentage.png")

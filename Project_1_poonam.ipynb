# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
CTE_student_data = './Clean_and_Combine.csv'
CTE_student_df = pd.read_csv(CTE_student_data)

CTE_student_df
# Out:
#        DISTRICT   SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0          1902   3101100          PRECALCULUS (PRE CALC)                9.0
# 1          1902   3220300             ENGLISH III (ENG 3)               12.0
# 2          1902   3220400              ENGLISH IV (ENG 4)               10.0
# 3          1902   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4          1902   3330100  UNITED STATES GOVERNMENT (GOVT                3.0
# 5          1902   3340100   US HISTORY STUDIES SINCE 1877                9.0
# 6          1902  13009900     PROFESSIONAL COMMUNICATIONS                3.0
# 7          1904   3220300             ENGLISH III (ENG 3)               10.0
# 8          1904   3220400              ENGLISH IV (ENG 4)               11.0
# 9          1904   3241400      COMMUNICATION APPLICATIONS                3.0
# 10         1904   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# ...

# %%
# Calculate the sum for cte students
cte_students_2015 = CTE_student_df["CTE_STUDENTS_2015"].sum()
cte_students_2016 = CTE_student_df["CTE_STUDENTS_2016"].sum()
cte_students_2017 = CTE_student_df["CTE_STUDENTS_2017"].sum()
cte_students_2018 = CTE_student_df["CTE_STUDENTS_2018"].sum()
all_students_2015 = CTE_student_df["ALL_STUDENTS_2015"].sum()
all_students_2016 = CTE_student_df["ALL_STUDENTS_2016"].sum()
all_students_2017 = CTE_student_df["ALL_STUDENTS_2017"].sum()
all_students_2018 = CTE_student_df["ALL_STUDENTS_2018"].sum()

# %%
N = 4
CTE_total = [cte_students_2015,cte_students_2016,cte_students_2017,cte_students_2018]
CTE_arr = tuple(CTE_total)


All_total = [all_students_2015,all_students_2016,all_students_2017,all_students_2018]
All_arr = tuple(All_total)
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, CTE_arr, width, color='b', yerr=None)
rects2 = ax.bar(ind + width, All_arr, width, color='y', yerr=None)
# add some text for labels, title and axes ticks
ax.set_ylabel('Counts')
ax.set_title('Count of all students and CTE students')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('2015', '2016', '2017','2018'))

ax.legend((rects1[0], rects2[0]), ('CTE Students', 'All Students'))

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Save an image of the chart and print it to the screen
plt.savefig("./Images/All_CTE_comparision.png")

# %%
import scipy.stats as stats
sample = CTE_student_df["CTE_AVG_2015"]
mean =CTE_student_df["ALL_AVG_2015"].mean()
stats.ttest_1samp(sample,mean)
# Out:
# Ttest_1sampResult(statistic=-0.9785016788013708, pvalue=0.32783819184757423)

# %%
import scipy.stats as stats
sample = CTE_student_df["CTE_AVG_2016"]
mean =CTE_student_df["ALL_AVG_2016"].mean()
stats.ttest_1samp(sample,mean)
# Out:
# Ttest_1sampResult(statistic=-1.4416610581036138, pvalue=0.14941379715595635)

# %%
import scipy.stats as stats
sample = CTE_student_df["CTE_AVG_2017"]
mean =CTE_student_df["ALL_AVG_2017"].mean()
stats.ttest_1samp(sample,mean)
# Out:
# Ttest_1sampResult(statistic=-0.8712062986018676, pvalue=0.3836520624652744)

# %%
import scipy.stats as stats
sample = CTE_student_df["CTE_AVG_2018"]
mean =CTE_student_df["ALL_AVG_2018"].mean()
stats.ttest_1samp(sample,mean)
# Out:
# Ttest_1sampResult(statistic=-0.8570181954603943, pvalue=0.3914451797945221)

# %%
import os
import pandas as pd
import matplotlib .pyplot as plt
import numpy as np

# %%
cte_data = pd.read_csv("Clean_and_Combine.csv")
cte_data.head()
# Out:
#    DISTRICT  SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0      1902  3101100          PRECALCULUS (PRE CALC)                9.0
# 1      1902  3220300             ENGLISH III (ENG 3)               12.0
# 2      1902  3220400              ENGLISH IV (ENG 4)               10.0
# 3      1902  3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4      1902  3330100  UNITED STATES GOVERNMENT (GOVT                3.0
#
#    CTE_HOURS_2015  CTE_AVG_2015  ALL_STUDENTS_2015  ALL_HOURS_2015  \
# 0            36.0           4.0               18.0            54.0
# 1            48.0           4.0               12.0            48.0
# 2            57.0           5.7               14.0            81.0
# 3             3.0           3.0                3.0             3.0
# 4             3.0           3.0                3.0             3.0
#
#    ALL_AVG_2015  CTE_STUDENTS_2016  ...  ALL_AVG_2017  CTE_STUDENTS_2018  \
# 0           3.0                9.0  ...           5.8               15.0
# 1           4.0               18.0  ...           5.8               15.0
# 2           5.8                7.0  ...           5.6               15.0
# 3           3.0               10.0  ...           3.0                6.0
# 4           3.0               12.0  ...           3.0                6.0
#
#    CTE_HOURS_2018  CTE_AVG_2018  ALL_STUDENTS_2018  ALL_HOURS_2018  \
# 0            45.0           3.0               15.0            45.0
# 1            90.0           6.0               17.0           102.0
# 2            81.0           5.4               15.0            81.0
# 3            18.0           3.0                6.0            18.0
# 4            18.0           3.0                6.0            18.0
#
#    ALL_AVG_2018    District  TEA District Type  TEA Description
# 0           3.0  CAYUGA ISD                  H            Rural
# 1           6.0  CAYUGA ISD                  H            Rural
# 2           5.4  CAYUGA ISD                  H            Rural
# 3           3.0  CAYUGA ISD                  H            Rural
# 4           3.0  CAYUGA ISD                  H            Rural
#
# [5 rows x 30 columns]

# %%
bins = [0, 2999999, 3200000, 3300000, 4000000, 2000000000]
group_labels = ["Misc","STEM","English","Social Sciences","CTE/Tech"]

# %%
cte_data["Course Type"] = pd.cut(cte_data["SERVICE"], bins, labels=group_labels)
cte_data
# Out:
#        DISTRICT   SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0          1902   3101100          PRECALCULUS (PRE CALC)                9.0
# 1          1902   3220300             ENGLISH III (ENG 3)               12.0
# 2          1902   3220400              ENGLISH IV (ENG 4)               10.0
# 3          1902   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4          1902   3330100  UNITED STATES GOVERNMENT (GOVT                3.0
# 5          1902   3340100   US HISTORY STUDIES SINCE 1877                9.0
# 6          1902  13009900     PROFESSIONAL COMMUNICATIONS                3.0
# 7          1904   3220300             ENGLISH III (ENG 3)               10.0
# 8          1904   3220400              ENGLISH IV (ENG 4)               11.0
# 9          1904   3241400      COMMUNICATION APPLICATIONS                3.0
# 10         1904   3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 11         1904   3330100  UNITED STATES GOVERNMENT (GOVT                3.0
# 12         1904   3340100   US HISTORY STUDIES SINCE 1877                3.0
# 13         1904   3350100              PSYCHOLOGY (PSYCH)                3.0
# 29                0.0           0.0                0.0             0.0
# ...               ...           ...                ...             ...
# 19812            24.0           4.0                9.0            27.0
# 19813            16.0           4.0                4.0            16.0
# 19814             3.0           3.0                3.0             3.0
# 19815             3.0           3.0                3.0             3.0
# 19816             3.0           3.0                3.0             3.0
# 19817             3.0           3.0                3.0             3.0
# 19818             3.0           3.0                3.0            12.0
# 19819            36.0           3.0               12.0            36.0
# 19820           276.0           5.6               54.0           306.0
# 19821             3.0           3.0                3.0             3.0
# 19822             3.0           3.0                3.0             3.0
# 19823            12.0           4.0                5.0            15.0
# 19824            30.0           3.0               14.0            42.0
# 19825            66.0           6.0               11.0            66.0
# 19826           117.0           3.0               48.0           144.0
# 19827            99.0           3.0               40.0           120.0
# 19828            64.0           4.0               16.0            64.0
# 19829            35.0           0.0                0.0            35.0
# 19830            36.0           4.0                9.0            36.0
# 19831            48.0           4.0               12.0            48.0
# 19832            18.0           3.0                6.0            18.0
# 19833           108.0           3.0               36.0           108.0
# 19834           129.0           3.0               43.0           129.0
# 19835            15.0           3.0                5.0            15.0
# 19836            15.0           3.0                5.0            15.0
# 19837            24.0           4.0                6.0            24.0
# 19838            27.0           3.0                9.0            27.0
# 19839            36.0           3.0               12.0            36.0
# 19840            18.0           3.0                6.0            18.0
# 19841            12.0           4.0                3.0            12.0
#
#        ALL_AVG_2018           District  TEA District Type  \
# 0               3.0         CAYUGA ISD                  H
# 1               6.0         CAYUGA ISD                  H
# 2               5.4         CAYUGA ISD                  H
# 3               3.0         CAYUGA ISD                  H
# 4               3.0         CAYUGA ISD                  H
# 5               5.9         CAYUGA ISD                  H
# 6               3.0         CAYUGA ISD                  H
# 7               4.7      FRANKSTON ISD                  H
# 8               3.8      FRANKSTON ISD                  H
# 9               3.0      FRANKSTON ISD                  H
# 10              3.0      FRANKSTON ISD                  H
# 11              3.5      FRANKSTON ISD                  H
# 12              4.0      FRANKSTON ISD                  H
# 13              0.0      FRANKSTON ISD                  H
# 14              3.0      FRANKSTON ISD                  H
# 15              0.0      FRANKSTON ISD                  H
# 16              6.0         NECHES ISD                  H
# 17              0.0         NECHES ISD                  H
# 18              5.2         NECHES ISD                  H
# 19              3.0         NECHES ISD                  H
# 20              0.0         NECHES ISD                  H
# 21              3.0         NECHES ISD                  H
# 22              3.0         NECHES ISD                  H
# 23              3.6         NECHES ISD                  H
# 24              3.0         NECHES ISD                  H
# 25              3.0         NECHES ISD                  H
# 26              0.0         NECHES ISD                  H
# 27              3.0         NECHES ISD                  H
# 28              0.0         NECHES ISD                  H
# 29              0.0         NECHES ISD                  H
# ...             ...                ...                ...
# 19812           3.0    ALBA-GOLDEN ISD                  H
# 19813           4.0    ALBA-GOLDEN ISD                  H
# 19814           3.0    DENVER CITY ISD                  G
# 19815           3.0    DENVER CITY ISD                  G
# 19816           3.0    DENVER CITY ISD                  G
# 19817           3.0         PLAINS ISD                  H
# 19818           4.0         PLAINS ISD                  H
# 19819           3.0         GRAHAM ISD                  G
# 19820           5.7         GRAHAM ISD                  G
# 19821           3.0         GRAHAM ISD                  G
# 19822           3.0         GRAHAM ISD                  G
# 19823           3.0         GRAHAM ISD                  G
# 19824           3.0         GRAHAM ISD                  G
# 19825           6.0          OLNEY ISD                  H
# 19826           3.0  ZAPATA COUNTY ISD                  D
# 19827           3.0  ZAPATA COUNTY ISD                  D
# 19828           4.0  ZAPATA COUNTY ISD                  D
# 19829           0.0  ZAPATA COUNTY ISD                  D
# 19830           4.0  ZAPATA COUNTY ISD                  D
# 19831           4.0  ZAPATA COUNTY ISD                  D
# 19832           3.0   CRYSTAL CITY ISD                  G
# 19833           3.0   CRYSTAL CITY ISD                  G
# 19834           3.0   CRYSTAL CITY ISD                  G
# 19835           3.0   CRYSTAL CITY ISD                  G
# 19836           3.0   CRYSTAL CITY ISD                  G
# 19837           4.0   CRYSTAL CITY ISD                  G
# 19838           3.0   CRYSTAL CITY ISD                  G
# 19839           3.0       LA PRYOR ISD                  H
# 19840           3.0       LA PRYOR ISD                  H
# 19841           4.0       LA PRYOR ISD                  H
#
#                    TEA Description      Course Type
# 0                            Rural             STEM
# 1                            Rural          English
# 2                            Rural          English
# 3                            Rural  Social Sciences
# 4                            Rural  Social Sciences
# 5                            Rural  Social Sciences
# 6                            Rural         CTE/Tech
# 7                            Rural          English
# 8                            Rural          English
# 9                            Rural          English
# 10                           Rural  Social Sciences
# 11                           Rural  Social Sciences
# 12                           Rural  Social Sciences
# 13                           Rural  Social Sciences
# 14                           Rural         CTE/Tech
# 15                           Rural         CTE/Tech
# 16                           Rural             STEM
# 17                           Rural             STEM
# 18                           Rural          English
# 19                           Rural          English
# 20                           Rural          English
# 21                           Rural          English
# 22                           Rural  Social Sciences
# 23                           Rural  Social Sciences
# 24                           Rural  Social Sciences
# 25                           Rural  Social Sciences
# 26                           Rural  Social Sciences
# 27                           Rural  Social Sciences
# 28                           Rural  Social Sciences
# 29                           Rural  Social Sciences
# ...                            ...              ...
# 19812                        Rural         CTE/Tech
# 19813                        Rural             Misc
# 19814      Non-metropolitan Stable          English
# 19815      Non-metropolitan Stable  Social Sciences
# 19816      Non-metropolitan Stable  Social Sciences
# 19817                        Rural          English
# 19818                        Rural  Social Sciences
# 19819      Non-metropolitan Stable             STEM
# 19820      Non-metropolitan Stable          English
# 19821      Non-metropolitan Stable          English
# 19822      Non-metropolitan Stable  Social Sciences
# 19823      Non-metropolitan Stable  Social Sciences
# 19824      Non-metropolitan Stable         CTE/Tech
# 19825                        Rural         CTE/Tech
# 19826  Other Central City Suburban  Social Sciences
# 19827  Other Central City Suburban         CTE/Tech
# 19828  Other Central City Suburban         CTE/Tech
# 19829  Other Central City Suburban         CTE/Tech
# 19830  Other Central City Suburban         CTE/Tech
# 19831  Other Central City Suburban         CTE/Tech
# 19832      Non-metropolitan Stable             STEM
# 19833      Non-metropolitan Stable             STEM
# 19834      Non-metropolitan Stable  Social Sciences
# 19835      Non-metropolitan Stable         CTE/Tech
# 19836      Non-metropolitan Stable         CTE/Tech
# 19837      Non-metropolitan Stable         CTE/Tech
# 19838      Non-metropolitan Stable         CTE/Tech
# 19839                        Rural          English
# 19840                        Rural  Social Sciences
# 19841                        Rural  Social Sciences
#
# [19842 rows x 31 columns]

# %%
type_courses = cte_data["Course Type"].value_counts()
type_courses
#combine math/science together called STEM
# Out:
# CTE/Tech           6951
# Social Sciences    6414
# English            3029
# STEM               2865
# Misc                580
# Name: Course Type, dtype: int64

# %%
#seperate out based on course type
cte = cte_data[cte_data['Course Type'] == "CTE/Tech"]
soc_sci = cte_data[cte_data['Course Type'] == "Social Sciences"]
english = cte_data[cte_data['Course Type'] == "English"]
stem = cte_data[cte_data['Course Type'] == "STEM"]
misc = cte_data[cte_data['Course Type'] == "Misc"]

# %%
#total course count for 2015,2016,2017,2018
#count of values for each year that are not equal to 0
cte_clean_15 = cte_data.loc[cte_data["CTE_HOURS_2015"] != 0]
count_15 = cte_clean_15["CTE_HOURS_2015"].count()

cte_clean_16 = cte_data.loc[cte_data["CTE_HOURS_2016"] != 0]
count_16 = cte_clean_16["CTE_HOURS_2016"].count()

cte_clean_17 = cte_data.loc[cte_data["CTE_HOURS_2017"] != 0]
count_17 = cte_clean_17["CTE_HOURS_2017"].count()

cte_clean_18 = cte_data.loc[cte_data["CTE_HOURS_2018"] != 0]
count_18 = cte_clean_18["CTE_HOURS_2018"].count()

# %%
#subject count for 2015

cte_15 = cte.loc[cte["CTE_HOURS_2015"] != 0]
cte_total_15 = cte_15['CTE_HOURS_2015'].count()

soc_sci_15 = soc_sci.loc[soc_sci["CTE_HOURS_2015"] != 0]
soc_sci_total_15 = soc_sci_15['CTE_HOURS_2015'].count()

english_15 = english.loc[english["CTE_HOURS_2015"] != 0]
english_total_15 = english_15['CTE_HOURS_2015'].count()

stem_15 = stem.loc[stem["CTE_HOURS_2015"] != 0]
stem_total_15 = stem_15['CTE_HOURS_2015'].count()

misc_15 = misc.loc[misc["CTE_HOURS_2015"] != 0]
misc_total_15 = misc_15['CTE_HOURS_2015'].count()

# %%
#percentages for 2015
cte_perc_15 = cte_total_15 / count_15*100
ss_perc_15 = soc_sci_total_15 / count_15*100
eng_perc_15 = english_total_15 / count_15*100
stem_perc_15 = stem_total_15 / count_15*100
misc_perc_15 = misc_total_15 / count_15*100

# %%
#pie chart for 2015
labels = ["CTE/Tech", "Social Sciences", "English", "STEM", "Misc"]
sizes = [cte_perc_15, ss_perc_15, eng_perc_15, stem_perc_15, misc_perc_15]
explode = (0.1, 0, 0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=325)
plt.title("% of Total Courses by Course Type 2015")
plt.axis('auto')
plt.savefig("Images/2015CourseData")
plt.show()

# %%
#subject count for 2016
cte_16 = cte.loc[cte["CTE_HOURS_2016"] != 0]
cte_total_16 = cte_16['CTE_HOURS_2016'].count()

soc_sci_16 = soc_sci.loc[soc_sci["CTE_HOURS_2016"] != 0]
soc_sci_total_16 = soc_sci_16['CTE_HOURS_2016'].count()

english_16 = english.loc[english["CTE_HOURS_2016"] != 0]
english_total_16 = english_16['CTE_HOURS_2016'].count()

stem_16 = stem.loc[stem["CTE_HOURS_2016"] != 0]
stem_total_16 = stem_16['CTE_HOURS_2016'].count()

misc_16 = misc.loc[misc["CTE_HOURS_2016"] != 0]
misc_total_16 = misc_16['CTE_HOURS_2016'].count()

# %%
#percentages for 2016
cte_perc_16 = cte_total_16 / count_16*100
ss_perc_16 = soc_sci_total_16/ count_16*100
eng_perc_16 = english_total_16 / count_16*100
stem_perc_16 = stem_total_16 / count_16*100
misc_perc_16 = misc_total_16 / count_16*100

# %%
#pie chart for 2016
labels = ["CTE/Tech", "Social Sciences", "English", "STEM", "Misc"]
sizes = [cte_perc_16, ss_perc_16, eng_perc_16, stem_perc_16, misc_perc_16]
explode = (0.1, 0, 0, 0, 0)


plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=325)
plt.title("% of Total Courses by Course Type 2016")
plt.axis('auto')
plt.savefig("Images/2016CourseData")
plt.show()

# %%
#subject count for 2017
cte_17 = cte.loc[cte["CTE_HOURS_2017"] != 0]
cte_total_17 = cte_17['CTE_HOURS_2017'].count()

soc_sci_17 = soc_sci.loc[soc_sci["CTE_HOURS_2017"] != 0]
soc_sci_total_17 = soc_sci_16['CTE_HOURS_2017'].count()

english_17 = english.loc[english["CTE_HOURS_2017"] != 0]
english_total_17 = english_17['CTE_HOURS_2017'].count()

stem_17 = stem.loc[stem["CTE_HOURS_2017"] != 0]
stem_total_17 = stem_17['CTE_HOURS_2017'].count()

misc_17 = misc.loc[misc["CTE_HOURS_2017"] != 0]
misc_total_17 = misc_17['CTE_HOURS_2017'].count()

# %%
#percentages for 2017
cte_perc_17 = cte_total_17 / count_17*100
ss_perc_17 = soc_sci_total_17 / count_17*100
eng_perc_17 = english_total_17 / count_17*100
stem_perc_17 = stem_total_17 / count_17*100
misc_perc_17 = misc_total_17 / count_17*100

# %%
#pie chart for 2017
labels = ["CTE/Tech", "Social Sciences", "English", "STEM", "Misc"]
sizes = [cte_perc_17, ss_perc_17, eng_perc_17, stem_perc_17, misc_perc_17]
explode = (0.1, 0, 0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=325)
plt.title("% of Total Courses by Course Type 2017")
plt.axis('auto')
plt.savefig("Images/2017CourseData")
plt.show()

# %%
#subject count for 2018
cte_18 = cte.loc[cte["CTE_HOURS_2018"] != 0]
cte_total_18 = cte_18['CTE_HOURS_2018'].count()

soc_sci_18 = soc_sci.loc[soc_sci["CTE_HOURS_2018"] != 0]
soc_sci_total_18 = soc_sci_18['CTE_HOURS_2018'].count()

english_18 = english.loc[english["CTE_HOURS_2018"] != 0]
english_total_18 = english_18['CTE_HOURS_2018'].count()

stem_18 = stem.loc[stem["CTE_HOURS_2018"] != 0]
stem_total_18 = stem_18['CTE_HOURS_2018'].count()

misc_18 = misc.loc[misc["CTE_HOURS_2018"] != 0]
misc_total_18 = misc_18['CTE_HOURS_2018'].count()

# %%
#percentages for 2018
cte_perc_18 = cte_total_18 / count_18*100
ss_perc_18 = soc_sci_total_18 / count_18*100
eng_perc_18 = english_total_18 / count_18*100
stem_perc_18 = stem_total_18 / count_18*100
misc_perc_18 = misc_total_18 / count_18*100

# %%
#pie chart for 2018
labels = ["CTE/Tech", "Social Sciences", "English", "STEM", "Misc"]
sizes = [cte_perc_18, ss_perc_18, eng_perc_18, stem_perc_18, misc_perc_18]
explode = (0.1, 0, 0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=325)
plt.title("% of Total Courses by Course Type 2018")
plt.axis('auto')
plt.savefig("Images/2018CourseData")
plt.show()
